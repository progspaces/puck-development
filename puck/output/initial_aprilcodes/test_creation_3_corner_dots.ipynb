# %%
import puck.code_modules.sheet_creation.sheets as sheets
# Out:
# ['#000000' '#FD1622' '#00FE16' '#0084FE' '#000000' '#FD1622' '#00FE16'
#  '#0084FE' '#000000' '#FD1622' '#00FE16' '#0084FE']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import puck.code_modules.sheet_creation.sheets as sheets
#
# File ~/Desktop/Repositories/puck/puck/puck/code_modules/sheet_creation/sheets.py:112
#     108     fig.savefig(f"puck/output/sheets/p{n_col}/p{n_col}_calibration.pdf")
#     111 # create_cal_sheet()
# --> 112 sheet_maker_3s(0,custom2,n_col = 3, spacing_n= .1, show_or_save= "save" )
#
# File ~/Desktop/Repositories/puck/puck/puck/code_modules/sheet_creation/sheets.py:87, in sheet_maker_3s(int_value, colour_pal, n_col, spacing_n, show_or_save)
#      85 # plt.show()
#      86 if show_or_save == "save":
# ---> 87     fig.savefig(f"puck/output/sheets/p{n_col}/permutations/p{n_col}_{int_value}.png", dpi=1000)
# ...

# %%
sheets.custom2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sheets.custom2
#
# NameError: name 'sheets' is not defined

# %%
sheets.sheet_maker_3s(0, sheets.custom2,n_col = 3, spacing_n= .1, show_or_save= "dshow" )
# Out:
# ['#000000' '#FD1622' '#00FE16' '#0084FE' '#000000' '#FD1622' '#00FE16'
#  '#0084FE' '#000000' '#FD1622' '#00FE16' '#0084FE']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sheets.sheet_maker_3s(0, sheets.custom2,n_col = 3, spacing_n= .1, show_or_save= "save" )
#
# File ~/Desktop/Repositories/puck/puck/puck/code_modules/sheet_creation/sheets.py:87, in sheet_maker_3s(int_value, colour_pal, n_col, spacing_n, show_or_save)
#      85 # plt.show()
#      86 if show_or_save == "save":
# ---> 87     fig.savefig(f"puck/output/sheets/p{n_col}/permutations/p{n_col}_{int_value}.png", dpi=1000)
#      88     fig.savefig(f"puck/output/sheets/p{n_col}/permutations/p{n_col}_{int_value}.pdf")
#      89 elif show_or_save == "show":
#
# ...
